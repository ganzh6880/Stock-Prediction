# %%
import torch
import torch.nn as nn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# This relates to plotting datetime values with matplotlib:
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df = pd.read_csv('FB.csv',index_col=0,parse_dates=True)
len(df)
# Out:
# 1995

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2012-05-18  42.049999  45.000000  38.000000  38.230000  38.230000  573576400
# 2012-05-21  36.529999  36.660000  33.000000  34.029999  34.029999  168192700
# 2012-05-22  32.610001  33.590000  30.940001  31.000000  31.000000  101786600
# 2012-05-23  31.370001  32.500000  31.360001  32.000000  32.000000   73600000
# 2012-05-24  32.950001  33.209999  31.770000  33.029999  33.029999   50237200

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df = df.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'],axis=1)

# %%
df
# Out:
#                  Close
# Date
# 2012-05-18   38.230000
# 2012-05-21   34.029999
# 2012-05-22   31.000000
# 2012-05-23   32.000000
# 2012-05-24   33.029999
# ...                ...
# 2020-04-17  179.240005
# 2020-04-20  178.240005
# 2020-04-21  170.800003
# 2020-04-22  182.279999
# 2020-04-23  185.130005
#
# [1995 rows x 1 columns]

# %%
plt.figure(figsize=(12,4))
plt.title('Facebook Price')
plt.ylabel('Price')
plt.grid(True)
plt.autoscale(axis='x',tight=True)
plt.plot(df['Close'])
plt.show()

# %%
# Extract values from the source .csv file
y = df['Close'].values.astype(float)

# Define a test size
test_size = 180

# Create train and test sets
train_set = y[:-test_size]
test_set = y[-test_size:]

# %%
from sklearn.preprocessing import MinMaxScaler

# Instantiate a scaler with a feature range from -1 to 1
scaler = MinMaxScaler(feature_range=(-1, 1))

# %%
train_norm = scaler.fit_transform(train_set.reshape(-1, 1))

# %%
# Convert train_norm from an array to a tensor
train_norm = torch.FloatTensor(train_norm).view(-1)

# Define a window size
window_size = 60

# Define function to create seq/label tuples
def input_data(seq,ws):  # ws is the window size
    out = []
    L = len(seq)
    for i in range(L-ws):
        window = seq[i:i+ws]
        label = seq[i+ws:i+ws+1]
        out.append((window,label))
    return out

# Apply the input_data function to train_norm
train_data = input_data(train_norm,window_size)
len(train_data)  # this should equal 325-12-12
# Out:
# 1755

# %%
# Display the first seq/label tuple in the train data
train_data[0]
# Out:
# (tensor([-0.7948, -0.8368, -0.8671, -0.8571, -0.8468, -0.8580, -0.8888, -0.8953,
#          -0.8812, -0.9000, -0.9082, -0.9185, -0.9091, -0.9141, -0.9062, -0.9071,
#          -0.9032, -0.9045, -0.8943, -0.8771, -0.8630, -0.8580, -0.8611, -0.8587,
#          -0.8466, -0.8565, -0.8461, -0.8548, -0.8635, -0.8661, -0.8694, -0.8651,
#          -0.8624, -0.8598, -0.8554, -0.8624, -0.8674, -0.8690, -0.8700, -0.8947,
#          -0.8963, -0.8861, -0.8872, -0.8896, -0.8897, -0.8927, -0.8838, -0.9087,
#          -0.9401, -0.9457, -0.9602, -0.9685, -0.9769, -0.9664, -0.9581, -0.9701,
#          -0.9701, -0.9672, -0.9592, -0.9613]),
#  tensor([-0.9735]))

# %%
class LSTMnetwork(nn.Module):
    def __init__(self,input_size=1,hidden_size=50,num_layers=2,output_size=1):
        super().__init__()
        self.hidden_size = hidden_size
        
        # Add an LSTM layer:
        self.lstm = nn.LSTM(input_size,hidden_size,num_layers)
        
        # Add a fully-connected layer:
        self.linear = nn.Linear(hidden_size,output_size)
        
        # Initialize h0 and c0:
        self.hidden = (torch.zeros(1,1,self.hidden_size),
                       torch.zeros(1,1,self.hidden_size))

    def forward(self,seq):
        lstm_out, self.hidden = self.lstm(
            seq.view(len(seq),1,-1), self.hidden)
        pred = self.linear(lstm_out.view(len(seq),-1))
        return pred[-1]  # we only want the last value

# %%
model = LSTMnetwork()

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

model
# Out:
# LSTMnetwork(
#   (lstm): LSTM(1, 50, num_layers=2)
#   (linear): Linear(in_features=50, out_features=1, bias=True)
# )

# %%
def count_parameters(model):
    params = [p.numel() for p in model.parameters() if p.requires_grad]
    for item in params:
        print(f'{item:>6}')
    print(f'______\n{sum(params):>6}')
    
count_parameters(model)
# Out:
#    200
#  10000
#    200
#    200
#  10000
#  10000
#    200
#    200
#     50
#      1
# ______
#  31051

# %%
epochs = 50

import time
start_time = time.time()

model = model.cuda()

for epoch in range(epochs):
    
    i=1
    
    # extract the sequence & label from the training data
    for seq, y_train in train_data:
        
        seq = seq.cuda()
        y_train = y_train.cuda()
        
        # reset the parameters and hidden states
        optimizer.zero_grad()
        model.hidden = (torch.zeros(2,1,model.hidden_size).cuda(),
                        torch.zeros(2,1,model.hidden_size).cuda())
        
        y_pred = model(seq)
        
        loss = criterion(y_pred, y_train)
        loss.backward()
        optimizer.step()
        
        
        if i%100 == 0:
            print(f'Epoch {epoch+1:2} Batch {i} Loss:{loss.item():10.8f}')
        i+=1
        
    # print training result
    print(f'Epoch: {epoch+1:2} Loss: {loss.item():10.8f}')
    
print(f'\nDuration: {time.time() - start_time:.0f} seconds')
# Out:
# Epoch  1 Batch 100 Loss:0.00080715
# Epoch  1 Batch 200 Loss:0.00009065
# Epoch  1 Batch 300 Loss:0.00011668
# Epoch  1 Batch 400 Loss:0.00009615
# Epoch  1 Batch 500 Loss:0.00086768
# Epoch  1 Batch 600 Loss:0.00045357
# Epoch  1 Batch 700 Loss:0.00000548
# Epoch  1 Batch 800 Loss:0.00227989
# Epoch  1 Batch 900 Loss:0.00024973
# Epoch  1 Batch 1000 Loss:0.00329789
# Epoch  1 Batch 1100 Loss:0.00000000
# Epoch  1 Batch 1200 Loss:0.00120536
# Epoch  1 Batch 1300 Loss:0.00024838
# Epoch  1 Batch 1400 Loss:0.00008609
# Epoch  1 Batch 1500 Loss:0.09440459
# Epoch  1 Batch 1600 Loss:0.02572287
# Epoch  1 Batch 1700 Loss:0.00574529
# Epoch:  1 Loss: 0.02943794
# Epoch  2 Batch 100 Loss:0.00024389
# Epoch  2 Batch 200 Loss:0.00002534
# Epoch  2 Batch 300 Loss:0.00002866
# Epoch  2 Batch 400 Loss:0.00014339
# Epoch  2 Batch 500 Loss:0.00098096
# Epoch  2 Batch 600 Loss:0.00030720
# Epoch  2 Batch 700 Loss:0.00005699
# Epoch  2 Batch 800 Loss:0.00492433
# Epoch  2 Batch 900 Loss:0.00066264
# ...

# %%
future = 180

# Add the last window of training values to the list of predictions
preds = []
pred_data = train_norm.tolist()

model = model.cpu()

# Set the model to evaluation mode
model.eval()

for i in range(len(df)-window_size):
    seq = torch.FloatTensor(pred_data[i:i+window_size])
    with torch.no_grad():
        model.hidden = (torch.zeros(2,1,model.hidden_size),
                        torch.zeros(2,1,model.hidden_size))
        if i > len(df)-window_size-future-1:
            pred_data.append(model(seq).item())
        preds.append(model(seq).item())

# %%
# Display predicted values
preds
len(preds)
# Out:
# 1935

# %%
true_predictions = scaler.inverse_transform(np.array(preds).reshape(-1, 1))
true_predictions
# Out:
# array([[ 44.24324688],
#        [ 43.84909409],
#        [ 44.45683859],
#        ...,
#        [185.59714055],
#        [185.43646453],
#        [185.6056304 ]])

# %%
df['Close'][-future:]
# Out:
# Date
# 2019-08-07    185.149994
# 2019-08-08    190.160004
# 2019-08-09    187.850006
# 2019-08-12    185.369995
# 2019-08-13    188.449997
#                  ...
# 2020-04-17    179.240005
# 2020-04-20    178.240005
# 2020-04-21    170.800003
# 2020-04-22    182.279999
# 2020-04-23    185.130005
# Name: Close, Length: 180, dtype: float64

# %%
df.index
x = df.index.to_numpy().astype('datetime64[D]')
x = x[60:]
len(x)
# Out:
# 1935

# %%
plt.figure(figsize=(12,4))
plt.title('Beer, Wine, and Alcohol Sales')
plt.ylabel('Sales (millions of dollars)')
plt.grid(True)
plt.autoscale(axis='x',tight=True)
plt.plot(df['Close'])
plt.plot(x,true_predictions)
plt.show()

# %%
# Plot the end of the graph
fig = plt.figure(figsize=(12,4))
plt.title('Beer, Wine, and Alcohol Sales')
plt.ylabel('Sales (millions of dollars)')
plt.grid(True)
plt.autoscale(axis='x',tight=True)
fig.autofmt_xdate()

# Select the end of the graph with slice notation:
plt.plot(df['Close'][-180:])
plt.plot(x[-180:],true_predictions[-180:])
plt.show()

# %%
epochs = 100

model = model.cuda()

# set model to back to training mode
model.train()

# feature scale the entire dataset
y_norm = scaler.fit_transform(y.reshape(-1, 1))
y_norm = torch.FloatTensor(y_norm).view(-1)
all_data = input_data(y_norm,window_size)

import time
start_time = time.time()

for epoch in range(epochs):
    
    i=1
    
    # train on the full set of sequences
    for seq, y_train in all_data:  
        
        seq = seq.cuda()
        y_train = y_train.cuda()
        
        # reset the parameters and hidden states
        optimizer.zero_grad()
        model.hidden = (torch.zeros(2,1,model.hidden_size).cuda(),
                        torch.zeros(2,1,model.hidden_size).cuda())
        
        y_pred = model(seq)
        
        loss = criterion(y_pred, y_train)
        loss.backward()
        optimizer.step()
        
        if i%100 == 0:
            print(f'Epoch {epoch+1:2} Batch {i} Loss:{loss.item():10.8f}')
        i+=1
        
    # print training result
    print(f'Epoch: {epoch+1:2} Loss: {loss.item():10.8f}')
    
print(f'\nDuration: {time.time() - start_time:.0f} seconds')
# Out:
# Epoch  1 Batch 100 Loss:0.00000235
# Epoch  1 Batch 200 Loss:0.00006741
# Epoch  1 Batch 300 Loss:0.00007192
# Epoch  1 Batch 400 Loss:0.00001238
# Epoch  1 Batch 500 Loss:0.00000001
# Epoch  1 Batch 600 Loss:0.00000055
# Epoch  1 Batch 700 Loss:0.00016627
# Epoch  1 Batch 800 Loss:0.00000310
# Epoch  1 Batch 900 Loss:0.00000198
# Epoch  1 Batch 1000 Loss:0.00023258
# Epoch  1 Batch 1100 Loss:0.00005244
# Epoch  1 Batch 1200 Loss:0.00022445
# Epoch  1 Batch 1300 Loss:0.00003191
# Epoch  1 Batch 1400 Loss:0.00015114
# Epoch  1 Batch 1500 Loss:0.00000063
# Epoch  1 Batch 1600 Loss:0.01199813
# Epoch  1 Batch 1700 Loss:0.00241808
# Epoch  1 Batch 1800 Loss:0.00000251
# Epoch  1 Batch 1900 Loss:0.00030883
# Epoch:  1 Loss: 0.00003476
# Epoch  2 Batch 100 Loss:0.00000562
# Epoch  2 Batch 200 Loss:0.00010664
# Epoch  2 Batch 300 Loss:0.00005948
# Epoch  2 Batch 400 Loss:0.00000845
# Epoch  2 Batch 500 Loss:0.00000080
# Epoch  2 Batch 600 Loss:0.00000001
# ...

# %%
window_size = 60
future = 60
L = len(y)

preds = []
pred_data = y_norm.tolist()

model = model.cpu()

model.eval()
for i in range(len(df)):  
    seq = torch.FloatTensor(pred_data[i:i+window_size])
    with torch.no_grad():
        # Reset the hidden parameters here!
        model.hidden = (torch.zeros(2,1,model.hidden_size),
                        torch.zeros(2,1,model.hidden_size)) 
        if i > len(df)-future-1:
            pred_data.append(model(seq).item())
        preds.append(model(seq).item())

# Inverse-normalize the prediction set
true_predictions = scaler.inverse_transform(np.array(preds).reshape(-1, 1))
print(true_predictions)

# PLOT THE RESULT
# Set a data range for the predicted data.
# Remember that the stop date has to be later than the last predicted value.
print(type(x))
df_new = np.arange('2020-04-24', '2020-06-23', dtype='datetime64[D]').astype('datetime64[D]')
x = np.concatenate((x,df_new), axis=None)
print(x)

plt.figure(figsize=(12,4))
plt.title('Beer, Wine, and Alcohol Sales')
plt.ylabel('Sales (millions of dollars)')
plt.grid(True)
plt.autoscale(axis='x',tight=True)
plt.plot(df['Close'])
plt.plot(x,true_predictions)
plt.show()
# Out:
# [[ 39.79936448]
#  [ 39.37566782]
#  [ 40.02589294]
#  ...
#  [210.98050681]
#  [205.79807113]
#  [202.13222721]]
# <class 'numpy.ndarray'>
# ['2012-08-14' '2012-08-15' '2012-08-16' ... '2020-06-20' '2020-06-21'
#  '2020-06-22']

# %%
fig = plt.figure(figsize=(12,4))
plt.title('Beer, Wine, and Alcohol Sales')
plt.ylabel('Sales (millions of dollars)')
plt.grid(True)
plt.autoscale(axis='x',tight=True)
fig.autofmt_xdate()
plt.plot(df['Close'][-100:])
plt.plot(x[-100:],true_predictions[-100:])
plt.show()

# %%
torch.save(model.state_dict(), 'Facebook_Pred.net')
